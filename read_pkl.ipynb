# %%
import pickle

path = '/home/vlab/Documents/Repositories/Foundational_models/CT-FM/notebooks/data-download/scan_list.pkl'
 
with open(path, 'rb') as f:
    data = pickle.load(f)
data
# Out:
# [PosixPath('/mnt/data1/IDC/ibro/IDC_SSL_CT/scans/qin_breast/QIN-BREAST-01-0036/1.3.6.1.4.1.14519.5.2.1.8162.7003.148415414316847321641731547599/1.3.6.1.4.1.14519.5.2.1.8162.7003.208161371828786682506011542150/scan.nrrd'),
#  PosixPath('/mnt/data1/IDC/ibro/IDC_SSL_CT/scans/qin_breast/QIN-BREAST-01-0036/1.3.6.1.4.1.14519.5.2.1.8162.7003.781711949998067399592528103164/1.3.6.1.4.1.14519.5.2.1.8162.7003.860223532466224782701655550475/scan.nrrd'),
#  PosixPath('/mnt/data1/IDC/ibro/IDC_SSL_CT/scans/qin_breast/QIN-BREAST-01-0036/1.3.6.1.4.1.14519.5.2.1.8162.7003.262110288321699292477612774355/1.3.6.1.4.1.14519.5.2.1.8162.7003.215624356344930345703986742705/scan.nrrd'),
#  PosixPath('/mnt/data1/IDC/ibro/IDC_SSL_CT/scans/qin_breast/QIN-BREAST-01-0030/1.3.6.1.4.1.14519.5.2.1.8162.7003.290448203046205004055182692923/1.3.6.1.4.1.14519.5.2.1.8162.7003.537837529146159550959250622009/scan.nrrd'),
# ...

# %%
# path = '/home/vlab/Documents/Repositories/Foundational_models/CT-FM/scan_list.pkl'
import pickle

path = 'scan_list.pkl'
path = '/data/home/jaruanob/Documents/Repositories/Foundational_models/Experiments/CT-FM/1761724264/scan_list.pkl'
 
with open(path, 'rb') as f:
    data = pickle.load(f)
print(len(data))
# Out:
# 516

# %%
mod_data = []
for item in data:
  mod_item = item.replace('')
# Out:
# ['/home/vlab/Documents/Collections/Dental/STS-Tooth/STS-3D-Tooth/Integrity/Labeled/Image/Integrity_L_001.nii.gz',
#  '/home/vlab/Documents/Collections/Dental/STS-Tooth/STS-3D-Tooth/Integrity/Labeled/Image/Integrity_L_002.nii.gz',
#  '/home/vlab/Documents/Collections/Dental/STS-Tooth/STS-3D-Tooth/Integrity/Labeled/Image/Integrity_L_003.nii.gz',
#  '/home/vlab/Documents/Collections/Dental/STS-Tooth/STS-3D-Tooth/Integrity/Labeled/Image/Integrity_L_004.nii.gz',
#  '/home/vlab/Documents/Collections/Dental/STS-Tooth/STS-3D-Tooth/Integrity/Labeled/Image/Integrity_L_005.nii.gz',
#  '/home/vlab/Documents/Collections/Dental/STS-Tooth/STS-3D-Tooth/Integrity/Labeled/Image/Integrity_L_006.nii.gz',
#  '/home/vlab/Documents/Collections/Dental/STS-Tooth/STS-3D-Tooth/Integrity/Labeled/Image/Integrity_L_007.nii.gz',
#  '/home/vlab/Documents/Collections/Dental/STS-Tooth/STS-3D-Tooth/Integrity/Labeled/Image/Integrity_L_008.nii.gz',
# ...

# %%
text = "banana"
updated_text = text.replace("an", "o")
print(updated_text)
# Out:
# booa
