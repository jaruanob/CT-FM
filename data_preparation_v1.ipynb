# %%
import os
import csv
import pandas as pd
import pickle
import time
import random

# %% [markdown]
# ### Preparation of Dental data

# %% [markdown]
# #### 1. Construct dataframe with all information

# %%
root_path = "/home/vlab/Documents/Collections/Dental"

collections_list = ["STS-Tooth",
                    # "Medicim", 
                    "Xiang_li"]

list_files = []
list_error_files = []
df_data = []
for collection_name in collections_list:
    db_path = os.path.join(root_path, collection_name, "db_organization.csv")
    df = pd.read_csv(db_path)
    relative_paths = df["relative_path"].tolist()
    file_names = df["file_name"].tolist()

    for idx, row in df.iterrows():
        if row["useful"] != 1: continue
        if row['file_name'] in relative_paths[idx]:
            relative_paths[idx] = relative_paths[idx].replace(row['file_name'], "")

        file_path = os.path.join(
            root_path, collection_name, relative_paths[idx], row['file_name']
        )
        if not os.path.exists(file_path):
            list_error_files.append(file_path)
            print("ERROR", collection_name, file_path)
        list_files.append(file_path)
        if row['file_name'].endswith(".nii.gz"):
          file_name_noext = row['file_name'][:-7]
        else:
          file_name_noext = row['file_name'][:-4]
          
        df_data.append(
            {
                "database": collection_name,
                "relative_path": relative_paths[idx],
                "file_name": row['file_name'],
                "full_path": file_path,
                "id_name":collection_name +'_'+ file_name_noext
            }
        )

# dataframe_path = 'database_dental.csv'
# pd.DataFrame(df_data).to_csv(dataframe_path, index=False)

# %% [markdown]
# #### 2. Convert data to nrrd using plastimatch_convert.sh which read the database_dental.csv file

# %% [markdown]
# #### 3. Create scan_list.pkl completo

# %%
path_nrrd_files = '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/'
# path_nrrd_files = '/home/vlab/Documents/Collections/Dental/CT-FM_data_v1/'

list_files = os.listdir(path_nrrd_files)
print(list_files)
print(len(list_files))

root_data_path = '/data/home/jaruanob/Documents/Repositories/Foundational_models/Experiments/CT-FM'
# root_data_path = '/home/vlab/Documents/Repositories/Foundational_models/Experiments/CT-FM'

# expe_name = 'test'
expe_name = str(int(time.time()))
# expe_name = '1761820031'
expe_path = os.path.join(root_data_path,expe_name)
if not os.path.exists(expe_path): os.mkdir(expe_path)

pkl_name = 'scan_list-CT-FM_data_v1.pkl'
pkl_path = os.path.join(expe_path,pkl_name)

list_path_files = []
for file_name in list_files:
  list_path_files.append(os.path.join(path_nrrd_files,file_name))

with open(pkl_path, 'wb') as file:
    pickle.dump(list_path_files, file)
    
print(list_path_files)
print('Expe name:', expe_path)
# Out:
# ['STS-Tooth_Integrity_U_149.nrrd', 'Xiang_li_054_cbct.nrrd', 'STS-Tooth_Integrity_U_102.nrrd', 'STS-Tooth_Integrity_U_066.nrrd', 'Xiang_li_227_cbct.nrrd', 'Xiang_li_279_cbct.nrrd', 'Xiang_li_091_cbct.nrrd', 'Xiang_li_134_cbct.nrrd', 'Xiang_li_142_cbct.nrrd', 'Xiang_li_294_cbct.nrrd', 'STS-Tooth_Integrity_U_191.nrrd', 'STS-Tooth_Integrity_U_057.nrrd', 'Xiang_li_022_cbct.nrrd', 'Xiang_li_187_cbct.nrrd', 'STS-Tooth_Integrity_U_178.nrrd', 'Xiang_li_251_cbct.nrrd', 'STS-Tooth_Integrity_U_097.nrrd', 'Xiang_li_278_cbct.nrrd', 'STS-Tooth_Integrity_U_214.nrrd', 'Xiang_li_226_cbct.nrrd', 'Xiang_li_055_cbct.nrrd', 'STS-Tooth_Integrity_U_035.nrrd', 'STS-Tooth_Integrity_U_151.nrrd', 'Xiang_li_090_cbct.nrrd', 'Xiang_li_295_cbct.nrrd', 'Xiang_li_143_cbct.nrrd', 'STS-Tooth_Integrity_U_160.nrrd', 'STS-Tooth_Integrity_U_004.nrrd', 'STS-Tooth_Integrity_U_225.nrrd', 'STS-Tooth_Integrity_U_189.nrrd', 'Xiang_li_250_cbct.nrrd', 'Xiang_li_186_cbct.nrrd', 'Xiang_li_023_cbct.nrrd', 'Xiang_li_168_cbct.nrrd', 'STS-Tooth_Integrity_L_010.nrrd', 'Xiang_li_093_cbct.nrrd', 'Xiang_li_136_cbct.nrrd', 'STS-Tooth_Integrity_U_195.nrrd', 'STS-Tooth_Integrity_U_018.nrrd', 'Xiang_li_008_cbct.nrrd', 'STS-Tooth_Integrity_U_053.nrrd', 'STS-Tooth_Integrity_U_137.nrrd', 'Xiang_li_056_cbct.nrrd', 'Xiang_li_225_cbct.nrrd', 'STS-Tooth_Integrity_U_106.nrrd', 'STS-Tooth_Integrity_U_029.nrrd', 'Xiang_li_020_cbct.nrrd', 'Xiang_li_185_cbct.nrrd', 'Xiang_li_253_cbct.nrrd', 'STS-Tooth_Integrity_U_208.nrrd', 'Xiang_li_140_cbct.nrrd', 'Xiang_li_296_cbct.nrrd', 'Xiang_li_137_cbct.nrrd', 'Xiang_li_092_cbct.nrrd', 'STS-Tooth_Integrity_U_164.nrrd', 'Xiang_li_169_cbct.nrrd', 'Xiang_li_224_cbct.nrrd', 'Xiang_li_057_cbct.nrrd', 'STS-Tooth_Integrity_U_221.nrrd', 'Xiang_li_009_cbct.nrrd', 'STS-Tooth_Integrity_L_008.nrrd', 'Xiang_li_252_cbct.nrrd', 'STS-Tooth_Integrity_U_210.nrrd', 'Xiang_li_184_cbct.nrrd', 'Xiang_li_021_cbct.nrrd', 'STS-Tooth_Integrity_U_093.nrrd', 'Xiang_li_141_cbct.nrrd', 'STS-Tooth_Integrity_U_031.nrrd', 'STS-Tooth_Integrity_U_155.nrrd', 'Xiang_li_255_cbct.nrrd', 'Xiang_li_183_cbct.nrrd', 'Xiang_li_026_cbct.nrrd', 'Xiang_li_078_cbct.nrrd', 'Xiang_li_290_cbct.nrrd', 'STS-Tooth_Integrity_U_112.nrrd', 'STS-Tooth_Integrity_U_076.nrrd', 'Xiang_li_146_cbct.nrrd', 'STS-Tooth_Integrity_U_159.nrrd', 'Xiang_li_118_cbct.nrrd', 'STS-Tooth_Integrity_U_168.nrrd', 'Xiang_li_130_cbct.nrrd', 'Xiang_li_095_cbct.nrrd', 'STS-Tooth_Integrity_U_047.nrrd', 'STS-Tooth_Integrity_U_123.nrrd', 'Xiang_li_223_cbct.nrrd', 'STS-Tooth_Integrity_L_004.nrrd', 'Xiang_li_050_cbct.nrrd', 'STS-Tooth_Integrity_U_181.nrrd', 'Xiang_li_027_cbct.nrrd', 'Xiang_li_182_cbct.nrrd', 'STS-Tooth_Integrity_U_025.nrrd', 'STS-Tooth_Integrity_U_141.nrrd', 'Xiang_li_254_cbct.nrrd', 'STS-Tooth_Integrity_U_204.nrrd', 'Xiang_li_119_cbct.nrrd', 'Xiang_li_147_cbct.nrrd', 'Xiang_li_291_cbct.nrrd', 'STS-Tooth_Integrity_U_199.nrrd', 'Xiang_li_094_cbct.nrrd', 'Xiang_li_131_cbct.nrrd', 'STS-Tooth_Integrity_U_170.nrrd', 'STS-Tooth_Integrity_U_014.nrrd', 'Xiang_li_051_cbct.nrrd', 'Xiang_li_222_cbct.nrrd', 'STS-Tooth_Integrity_U_043.nrrd', 'STS-Tooth_Integrity_U_127.nrrd', 'STS-Tooth_Integrity_U_008.nrrd', 'Xiang_li_292_cbct.nrrd', 'Xiang_li_144_cbct.nrrd', 'Xiang_li_209_cbct.nrrd', 'Xiang_li_257_cbct.nrrd', 'STS-Tooth_Integrity_U_229.nrrd', 'STS-Tooth_Integrity_U_185.nrrd', 'Xiang_li_181_cbct.nrrd', 'Xiang_li_024_cbct.nrrd', 'Xiang_li_052_cbct.nrrd', 'STS-Tooth_Integrity_U_218.nrrd', 'STS-Tooth_Integrity_U_039.nrrd', 'STS-Tooth_Integrity_U_072.nrrd', 'Xiang_li_132_cbct.nrrd', 'Xiang_li_097_cbct.nrrd', 'Xiang_li_145_cbct.nrrd', 'Xiang_li_293_cbct.nrrd', 'Xiang_li_025_cbct.nrrd', 'Xiang_li_180_cbct.nrrd', 'Xiang_li_256_cbct.nrrd', 'Xiang_li_208_cbct.nrrd', 'STS-Tooth_Integrity_U_174.nrrd', 'STS-Tooth_Integrity_U_010.nrrd', 'Xiang_li_053_cbct.nrrd', 'Xiang_li_220_cbct.nrrd', 'STS-Tooth_Integrity_U_021.nrrd', 'STS-Tooth_Integrity_U_145.nrrd', 'STS-Tooth_Integrity_U_083.nrrd', 'Xiang_li_096_cbct.nrrd', 'Xiang_li_133_cbct.nrrd', 'STS-Tooth_Inte ...
# 515
# ['/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_149.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_054_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_102.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_066.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_227_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_279_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_091_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_134_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_142_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_294_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_191.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_057.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_022_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_187_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_178.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_251_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_097.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_278_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_214.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_226_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_055_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_035.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_151.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_090_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_295_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_143_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_160.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_004.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_225.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_189.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_250_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_186_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_023_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_168_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_L_010.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_093_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_136_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_195.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_018.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_008_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_053.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_137.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_056_cbct.nrrd', '/data/home/jaruanob ...
# Expe name: /data/home/jaruanob/Documents/Repositories/Foundational_models/Experiments/CT-FM/1761838706

# %% [markdown]
# #### 4. Create partitions fos train, validation and test

# %%
random.seed(1)
random.shuffle(list_path_files)

# Define split ratios
train_ratio = 0.75
val_ratio = 0.05
test_ratio = 0.20

# Compute split indices
n_total = len(list_path_files)
n_train = int(n_total * train_ratio)
n_val = int(n_total * val_ratio)

# Split
train_paths = list_path_files[:n_train]
val_paths = list_path_files[n_train:n_train + n_val]
test_paths = list_path_files[n_train + n_val:]

print("Train:", len(train_paths))
print(train_paths)
pkl_name = 'scan_list-CT-FM_data_v1_train.pkl'
with open(os.path.join(expe_path,pkl_name), 'wb') as file:
    pickle.dump(train_paths, file)
    
print("Validation:", len(val_paths))
print(val_paths)
pkl_name = 'scan_list-CT-FM_data_v1_validation.pkl'
with open(os.path.join(expe_path,pkl_name), 'wb') as file:
    pickle.dump(val_paths, file)

print("Test:", len(test_paths))
print(test_paths)
pkl_name = 'scan_list-CT-FM_data_v1_test.pkl'
with open(os.path.join(expe_path,pkl_name), 'wb') as file:
    pickle.dump(test_paths, file)
# Out:
# Train: 386
# ['/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_130_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_173_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_037.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_101.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_105.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_187.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_133_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_147.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_174_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_118_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_182_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_064.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_036.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_036_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_033.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_028.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_043_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_094_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_006.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_009_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_185_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_092_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_209.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_210.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_026_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_016_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_144.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_006_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_236_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_038.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_223_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_011_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_290_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_281_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_120.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_007.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_086_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_012_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_117.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_061_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_166.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_062_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_139_cbct.nrrd', '/data/home/jaruanob/Documen ...
# Validation: 25
# ['/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_181.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_064_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_233_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_124.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_267_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_203.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_066_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_074_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_151.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_107.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_081_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_079.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_277_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_175.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_035_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_100_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_123.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_120_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_169_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_072_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_217.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_121.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_106.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_116_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_107_cbct.nrrd']
# Test: 104
# ['/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_248_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_085_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_088.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_289_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_076_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_027_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_094.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_132.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_202_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_068_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_282_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_180_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_188_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_278_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_239_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_148.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_154.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_092.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_115.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_046.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_114_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_199.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_226.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_283_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_189_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_197_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_211.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_106_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_041.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_126.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_159_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_252_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_163_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_157.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_003.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_261_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_147_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_296_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_054.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_129_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/STS-Tooth_Integrity_U_104.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_166_cbct.nrrd', '/data/home/jaruanob/Documents/Collections/Dental/CT-FM_data_v1/Xiang_li_124_cbct.nrrd', '/data/home/jaruanob/Documents/Colle ...
