# %%
import pandas as pd

# %%
df = pd.read_csv("/mnt/ssd1/ibro/IDC_SSL_CT/idc_ssl_metadata.csv")

# %%
df
# Out:
#                                         SeriesInstanceUID    collection_id  \
# 0       1.3.6.1.4.1.14519.5.2.1.3344.4008.860298788877...        tcga_lihc
# 1       1.3.6.1.4.1.14519.5.2.1.99.1071.33684187058318...  covid_19_ny_sbu
# 2       1.3.6.1.4.1.14519.5.2.1.6919.4624.138851628559...        c4kc_kits
# 3       1.3.6.1.4.1.14519.5.2.1.99.1071.87665727850601...  covid_19_ny_sbu
# 4       1.3.6.1.4.1.14519.5.2.1.1600.1202.325534224666...          cmb_lca
# ...                                                   ...              ...
# 148389  1.3.6.1.4.1.14519.5.2.1.6655.2359.403049190755...   lung_pet_ct_dx
# 148390  1.3.6.1.4.1.14519.5.2.1.6919.4624.242293830530...        c4kc_kits
# 148391  1.3.6.1.4.1.14519.5.2.1.9203.4004.303118129739...        tcga_kirc
# 148392  1.3.6.1.4.1.14519.5.2.1.3344.4007.181354535054...          tcga_ov
# 148393  1.3.6.1.4.1.14519.5.2.1.1706.8374.205799640667...     hcc_tace_seg
#
#                 PatientID BodyPartExamined ContrastBolusAgent  \
# 0            TCGA-DD-A4NF            LIVER            APPLIED
# 1                 A072894              NaN                NaN
# 2              KiTS-00151          ABDOMEN            APPLIED
# 3                 A656786              NaN                NaN
# 4       CMB-LCA-MSB-01499              NaN                NaN
# ...                   ...              ...                ...
# 148389      Lung_Dx-A0010              NaN                NaN
# 148390         KiTS-00108          ABDOMEN                NaN
# 148391       TCGA-BP-4766           KIDNEY      BARIUM & OMNI
# 148392       TCGA-25-1633            OVARY                NaN
# 148393            HCC_029            LIVER                NaN
#
#                                  ImageType  num_instances  \
# 0       ORIGINAL/PRIMARY/AXIAL/CT_SOM5 SPI           1338
# 1                   ORIGINAL/PRIMARY/AXIAL           1243
# 2       ORIGINAL/PRIMARY/AXIAL/CT_SOM5 SPI           1059
# 3                   ORIGINAL/PRIMARY/AXIAL           1043
# 4                   ORIGINAL/PRIMARY/AXIAL           1023
# ...                                    ...            ...
# 148389              ORIGINAL/PRIMARY/AXIAL             51
# 148390  ORIGINAL/PRIMARY/AXIAL/CT_SOM5 SPI             51
# 148391              ORIGINAL/PRIMARY/AXIAL             51
# 148392  ORIGINAL/PRIMARY/AXIAL/CT_SOM5 SPI             51
# 148393              ORIGINAL/PRIMARY/AXIAL             51
#
#                                          StudyInstanceUID  \
# 0       1.3.6.1.4.1.14519.5.2.1.3344.4008.107965720766...
# 1       1.3.6.1.4.1.14519.5.2.1.99.1071.24446248762144...
# 2       1.3.6.1.4.1.14519.5.2.1.6919.4624.303439124400...
# 3       1.3.6.1.4.1.14519.5.2.1.99.1071.16946303853599...
# 4       1.3.6.1.4.1.14519.5.2.1.1600.1202.226547877360...
# ...                                                   ...
# 148389  1.3.6.1.4.1.14519.5.2.1.6655.2359.162822447891...
# 148390  1.3.6.1.4.1.14519.5.2.1.6919.4624.986013693303...
# 148391  1.3.6.1.4.1.14519.5.2.1.9203.4004.170587558620...
# 148392  1.3.6.1.4.1.14519.5.2.1.3344.4007.255229306322...
# 148393  1.3.6.1.4.1.14519.5.2.1.1706.8374.253437873837...
#
#        ClinicalTrialTimePointID             PixelSpacing  SliceThickness  \
# 0                           NaN      0.7890625/0.7890625            1.00
# 1                           -28        0.953125/0.953125            1.25
# 2                           -36  0.810546875/0.810546875            1.00
# 3                             0        0.703125/0.703125            1.25
# 4                          -698        0.703125/0.703125            1.25
# ...                         ...                      ...             ...
# 148389                      NaN        0.683594/0.683594            5.00
# 148390                      -10  0.865234375/0.865234375            5.00
# 148391                      NaN        0.552734/0.552734            2.50
# 148392                      NaN      0.6640625/0.6640625            5.00
# 148393                      105        0.703125/0.703125            5.00
#
#        ConvolutionKernel  ReconstructionDiameter        Manufacturer  \
# 0                   B31f                   404.0             SIEMENS
# 1               STANDARD                   488.0  GE MEDICAL SYSTEMS
# 2                 I30f/1                   415.0             SIEMENS
# 3               STANDARD                   360.0  GE MEDICAL SYSTEMS
# 4               STANDARD                   360.0  GE MEDICAL SYSTEMS
# ...                  ...                     ...                 ...
# 148389              LUNG                   350.0  GE MEDICAL SYSTEMS
# 148390              B31f                   443.0             SIEMENS
# 148391          STANDARD                   283.0  GE MEDICAL SYSTEMS
# 148392              B40f                   340.0             SIEMENS
# 148393          STANDARD                   360.0                 NaN
#
#                                                   idc_url
# 0       https://viewer.imaging.datacommons.cancer.gov/...
# 1       https://viewer.imaging.datacommons.cancer.gov/...
# 2       https://viewer.imaging.datacommons.cancer.gov/...
# 3       https://viewer.imaging.datacommons.cancer.gov/...
# 4       https://viewer.imaging.datacommons.cancer.gov/...
# ...                                                   ...
# 148389  https://viewer.imaging.datacommons.cancer.gov/...
# 148390  https://viewer.imaging.datacommons.cancer.gov/...
# 148391  https://viewer.imaging.datacommons.cancer.gov/...
# 148392  https://viewer.imaging.datacommons.cancer.gov/...
# 148393  https://viewer.imaging.datacommons.cancer.gov/...
#
# [148394 rows x 15 columns]

# %%
df["collection_id"].value_counts().reset_index().values.tolist()
# Out:
# [['nlst', 128037],
#  ['phantom_fda', 3576],
#  ['covid_19_ny_sbu', 1753],
#  ['ct_colonography', 1711],
#  ['acrin_nsclc_fdg_pet', 1283],
#  ['lidc_idri', 974],
#  ['4d_lung', 830],
#  ['tcga_kirc', 812],
#  ['lung_pet_ct_dx', 546],
#  ['hcc_tace_seg', 477],
#  ['nsclc_radiogenomics', 427],
#  ['nsclc_radiomics', 421],
#  ['tcga_blca', 409],
#  ['cptac_ucec', 393],
#  ['tcga_ov', 384],
#  ['c4kc_kits', 366],
#  ['cptac_ccrcc', 333],
#  ['tcga_ucec', 330],
#  ['cptac_pda', 305],
#  ['pediatric_ct_seg', 296],
#  ['tcga_lihc', 284],
#  ['acrin_flt_breast', 279],
#  ['anti_pd_1_lung', 265],
#  ['cmb_crc', 251],
#  ['tcga_stad', 237],
#  ['rider_lung_pet_ct', 235],
#  ['qiba_ct_1c', 211],
#  ['pancreatic_ct_cbct_seg', 200],
#  ['tcga_luad', 183],
#  ['stageii_colorectal_ct', 181],
#  ['midrc_ricord_1a', 163],
#  ['cptac_lscc', 159],
#  ['tcga_lusc', 133],
#  ['cptac_luad', 133],
#  ['cmb_mel', 124],
#  ['midrc_ricord_1b', 118],
#  ['pelvic_reference_data', 116],
#  ['covid_19_ar', 113],
#  ['qin_breast', 110],
#  ['cmb_lca', 107],
#  ['tcga_esca', 94],
#  ['nsclc_radiomics_genomics', 88],
#  ['naf_prostate', 74],
#  ['ctpred_sunitinib_pannet', 73],
#  ['spie_aapm_lung_ct_challenge', 70],
#  ['cptac_cm', 63],
#  ['rider_lung_ct', 63],
#  ['cptac_sar', 63],
#  ['lctsc', 60],
#  ['ct_vs_pet_ventilation_imaging', 59],
#  ['lungct_diagnosis', 52],
#  ['soft_tissue_sarcoma', 51],
#  ['tcga_kirp', 47],
#  ['qin_lung_ct', 39],
#  ['tcga_coad', 37],
#  ['tcga_kich', 33],
#  ['dro_toolkit', 32],
#  ['nsclc_radiomics_interobserver1', 22],
#  ['cmb_mml', 21],
#  ['breast_diagnosis', 18],
#  ['lung_fused_ct_pathology', 15],
#  ['tcga_prad', 13],
#  ['cmb_pca', 12],
#  ['tcga_thca', 11],
#  ['cmb_gec', 8],
#  ['pseudo_phi_dicom_data', 4],
#  ['tcga_read', 3],
#  ['tcga_sarc', 3],
#  ['lung_phantom', 1]]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df["BodyPartExamined"].value_counts()
# Out:
# CHEST               125320
# ABDOMEN               1965
# LUNG                  1775
# COLON                 1748
# LIVER                  761
# KIDNEY                 745
# OVARY                  384
# BREAST                 368
# BLADDER                341
# UTERUS                 314
# CHEST_TO_PELVIS        246
# STOMACH                237
# CHESTABDPELVIS         205
# Kidney                 148
# PELVIS                 115
# ESOPHAGUS               94
# PROSTATE                87
# PANCREAS                76
# EXTREMITY               51
# WHOLEBODY               37
# ABDOMENPELVIS           20
# CHESTABDOMEN            18
# ABD PEL                 16
# CHEST ABD PELVIS        14
# THORAX                  14
# THYROID                 11
# NECKCHESTABDPELV        10
# CAP                     10
# NECK TO PELVIS           9
# TH CT CHEST WO C         8
# J BRZUSZNA               6
# J brzuszna               6
# CT CHEST WO CE           6
# CT 3PHASE REN            4
# HEART                    4
# CHEST (THORAX) W         4
# ABD PELV                 3
# HEAD                     3
# CHEST COMPUTED T         3
# CTA CHEST                3
# RECTUM                   3
# Thorax                   2
# CT CHEST W_ENHAN         2
# FOOT                     2
# NECK                     1
# PET_CT SCAN CHES         1
# THORAX CT _AH05          1
# THORAXABD                1
# WO INTER                 1
# ABDOMEN_PELVIS C         1
# BD CT ABD WO_W C         1
# CT THORAX W CNT          1
# CHEST/ABD                1
# OUTSIDE FIL              1
# Name: BodyPartExamined, dtype: int64

# %%
df[df["BodyPartExamined"] == "FOOT"]
# Out:
#                                         SeriesInstanceUID collection_id  \
# 133213  1.3.6.1.4.1.14519.5.2.1.1600.1205.395827650434...       cmb_mel
# 133330  1.3.6.1.4.1.14519.5.2.1.1600.1205.426089899287...       cmb_mel
#
#                 PatientID BodyPartExamined ContrastBolusAgent  \
# 133213  CMB-MEL-MSB-01206             FOOT                NaN
# 133330  CMB-MEL-MSB-01206             FOOT                NaN
#
#                      ImageType  num_instances  \
# 133213  ORIGINAL/PRIMARY/AXIAL             83
# 133330  ORIGINAL/PRIMARY/AXIAL             83
#
#                                          StudyInstanceUID  \
# 133213  1.3.6.1.4.1.14519.5.2.1.1600.1205.152697021873...
# 133330  1.3.6.1.4.1.14519.5.2.1.1600.1205.152697021873...
#
#        ClinicalTrialTimePointID PixelSpacing  SliceThickness  \
# 133213                      -34  0.316/0.316             3.0
# 133330                      -34  0.316/0.316             3.0
#
#        ConvolutionKernel  ReconstructionDiameter Manufacturer  \
# 133213              FC08                 162.187      TOSHIBA
# 133330              FC81                 162.187      TOSHIBA
#
#                                                   idc_url
# 133213  https://viewer.imaging.datacommons.cancer.gov/...
# 133330  https://viewer.imaging.datacommons.cancer.gov/...
